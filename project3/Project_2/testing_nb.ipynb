# %%
from structure import pressure_guess, integrate
import eos
import astro_const as ac
import matplotlib.pyplot as plt

# %%
mue = 2

pguess = pressure_guess(ac.Msun,mue)

delta_m = .004 * ac.Msun
eta = 1e-24
xi = .0003

m,r,p = integrate(pguess,delta_m,eta,xi,mue,max_steps=10000)
pguess
# Out:
# 1.311232337733785e+24

# %%
len(m)
# Out:
# 9492

# %%
m
# Out:
# array([7.95363948e+27, 7.96079776e+27, 7.96796242e+27, ...,
#        6.05506023e+30, 6.05506023e+30, 6.05506023e+30])

# %%
r
# Out:
# array([ 370901.22463521,  371012.46204466,  371123.73281571, ...,
#        6125584.60469664, 6125584.60496275, 6125584.60520264])

# %%
p
# Out:
# array([1.31123234e+24, 1.31121636e+24, 1.31120038e+24, ...,
#        2.59926810e+00, 2.00562572e+00, 1.54756431e+00])

# %%
plt.plot(p)

# %%
plt.plot(r)

# %%
plt.plot(m)
